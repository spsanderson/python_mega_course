# %%
print(1)
print(2)
# Out:
# 1
# 2

# %%
print(3)
# Out:
# 3

# %%
print(4)
# Out:
# 4

# %%
data = [1,2,3,4]
for item in data:
    print(item)
# Out:
# 1
# 2
# 3
# 4

# %%
import pandas

# %%
# df = pandas.read_csv("C:\\Path\\file_name.csv")

# %%
from bs4 import BeautifulSoup
import requests
print(1)
# Out:
# 1

# %%
r = requests.get("https://en.wikipedia.org/wiki/Eagle")
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Eagle - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Eagle","wgTitle":"Eagle","wgCurRevisionId":833325343,"wgRevisionId":833325343,"wgArticleId":37602,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 German-language sources (de)","Webarchive template wayback links","Wikipedia semi-protected pages","Use dmy dates from May 2015","Articles with \'species\' microformats","Articles containing Latin-language text","Articles containing French-language text","Articles containing Old English-language text","Articles containing Greek-languag
# ...

# %%
soup = BeautifulSoup(r.content,"lxml")
soup = soup.prettify
print(soup)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Eagle - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...
